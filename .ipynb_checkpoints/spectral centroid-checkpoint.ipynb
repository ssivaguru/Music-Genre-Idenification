# %%
import os 
import librosa
import pandas as pd
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

# %%
GENRE_LIST=['metal','hiphop','reggae','rock','classical','jazz','blues','country','pop','disco']
print("Genre list ",GENRE_LIST)
# Out:
# Genre list  ['metal', 'hiphop', 'reggae', 'rock', 'classical', 'jazz', 'blues', 'country', 'pop', 'disco']

# %%
#Audio have already been converted to wav

# %%
#checking out a random audio file 
def plotdata(name):
    Data , SampeRate = librosa.load(name)
    plt.figure(figsize=(12, 4))
    librosa.display.waveplot(Data, sr=SampeRate)
    plt.title(name)

# %%
name = ["blues/blues.00000.wav",'metal/metal.00000.wav','hiphop/hiphop.00000.wav','reggae/reggae.00000.wav','rock/rock.00000.wav','classical/classical.00000.wav']
for n in name:
    plotdata(n)

# %%
# Out:
# [1784.16584954]

# %%
spectralcentroids=[]
samplerate=[]
label=[]
path=[]

# %%
#Todo modify method to return dataframe
def CreateDataSet(folder):
    columns=['data', 'samplerate', 'label', 'path']
    df = pd.DataFrame(columns=columns)
    for filename in os.listdir(folder):
        music_name=os.path.join(folder,filename)
        try:
            X, sample_rate = librosa.load(music_name, res_type='kaiser_fast')
            samplerate.append(sample_rate)
            label.append(folder)
            path.append(music_name)
            spectralcentroid = np.mean(librosa.feature.spectral_centroid(y=X,sr=sample_rate).T, axis=0)
            print(spectralcentroid.shape)
            spectralcentroids.append(spectralcentroid)
        except Exception as e:
            print("Error encountered while parsing file: ", e)
            return None
    return df

# %%
for folder in GENRE_LIST:
    print(folder)
    CreateDataSet(folder)
# Out:
# metal
# hiphop
# reggae
# rock
# classical
# jazz
# blues
# country
# pop
# disco

# %%
ndata = np.array(spectralcentroids)
y = np.array(label)
print(y)
# Out:
# ['metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop', 'hiphop
# ...

# %%
import seaborn as sns

plt.plot(ndata, y, color='blue', linewidth=3)

# %%
lb = LabelEncoder()

y = np_utils.to_categorical(lb.fit_transform(y))

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D, Conv2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = y.shape[1]

model = Sequential()

model.add(Dense(13, input_dim=10, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))

# %%
model.compile(optimizer='adam', 
              loss='mean_squared_error',
              metrics=['accuracy'])

# %%
X_train, X_val, y_train, y_val = train_test_split(ndata,y,test_size=.2,random_state=1)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=500,validation_data=(X_val,y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-e1a9c51136c8> in <module>()
# ----> 1 model.fit(X_train, y_train, batch_size=32, epochs=500,validation_data=(X_val,y_val))
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     953             sample_weight=sample_weight,
#     954             class_weight=class_weight,
# --> 955             batch_size=batch_size)
#     956         # Prepare validation data.
#     957         do_validation = False
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     752             feed_input_shapes,
# ...

# %%
y_train.shape
# Out:
# (800, 10)
